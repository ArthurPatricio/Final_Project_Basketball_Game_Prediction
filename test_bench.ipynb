# %%
#Import Libs

import pandas as pd
import requests
import json

# %%
#Get team's stats with NBA's API 

url_base = 'https://www.nba.com/stats/teams/boxscores-traditional'

headers = {
		'Host': 'stats.nba.com',
		'Connection': 'keep-alive',
		'Accept': 'application/json, text/plain, */*',
		'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/79.0.3945.130 Safari/537.36',
		'Referer': 'https://stats.nba.com/',
		"x-nba-stats-origin": "stats",
		"x-nba-stats-token": "true",
		'Accept-Encoding': 'gzip, deflate, br',
		'Accept-Language': 'en-US,en;q=0.9',
	}

columns_list = ['SEASON_YEAR',
                'TEAM_ID',
                'TEAM_ABBREVIATION',
                'TEAM_NAME',
                'GAME_ID',
                'GAME_DATE',
                'MATCHUP',
                'WL',
                'MIN',
                'FGM',
                'FGA',
                'FG_PCT',
                'FG3M',
                'FG3A',
                'FG3_PCT',
                'FTM',
                'FTA',
                'FT_PCT',
                'OREB',
                'DREB',
                'REB',
                'AST',
                'TOV',
                'STL',
                'BLK',
                'BLKA',
                'PF',
                'PFD',
                'PTS',
                'PLUS_MINUS',
                'GP_RANK',
                'W_RANK',
                'L_RANK',
                'W_PCT_RANK',
                'MIN_RANK',
                'FGM_RANK',
                'FGA_RANK',
                'FG_PCT_RANK',
                'FG3M_RANK',
                'FG3A_RANK',
                'FG3_PCT_RANK',
                'FTM_RANK',
                'FTA_RANK',
                'FT_PCT_RANK',
                'OREB_RANK',
                'DREB_RANK',
                'REB_RANK',
                'AST_RANK',
                'TOV_RANK',
                'STL_RANK',
                'BLK_RANK',
                'BLKA_RANK',
                'PF_RANK',
                'PFD_RANK',
                'PTS_RANK',
                'PLUS_MINUS_RANK',
                'TeamGameLogs']

dfs=[]

#for i in teams_ids:

parameters = {
    'DateFrom': '',
    'DateTo': '',
    'GameSegment': '',
    'LastNGames': 0,
    "LeagueID": "00",
    'Location': '',
    'MeasureType': "Base",
    'Month': 0,
    'OppTeamID' :0,
    'Outcome': '',
    'PORound': 0,
    'PerMode': "Totals",
    'Period': 0,
    'PlayerID': '',
    'SeasonSegment' : '',
    'SeasonType': "Regular Season",
    'SeasonYear': "2022-23",
    'ShotClockRange': '',  
    'TeamID': '1610612744',
    'VsConference': '',
    'VsDivision': ''	
}

response = requests.get(url_base, params=parameters, headers=headers).json()

# transform contents into dataframe
#results = response['resultSets'][0]['rowSet']
#df = pd.DataFrame(results, columns=columns_list)
#dfs.append(df)
#print(i)

# %%
game_dates = pd.read_excel('box_scores_Regular+Season.xlsx')
game_dates = game_dates['GAME_DATE']
game_dates.drop_duplicates(inplace=True)
game_dates.count
# Out:
# <bound method Series.count of 0        2023-04-09
# 30       2023-04-08
# 36       2023-04-07
# 58       2023-04-06
# 68       2023-04-05
#             ...
# 14044    2017-10-21
# 14066    2017-10-20
# 14086    2017-10-19
# 14092    2017-10-18
# 14114    2017-10-17
# Name: GAME_DATE, Length: 955, dtype: object>

# %%
import pandas as pd
import requests
import json
import tqdm

headers  = {
    'Connection': 'keep-alive',
    'Accept': 'application/json, text/plain, */*',
    'x-nba-stats-token': 'true',
    'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/79.0.3945.130 Safari/537.36',
    'x-nba-stats-origin': 'stats',
    'Sec-Fetch-Site': 'same-origin',
    'Sec-Fetch-Mode': 'cors',
    'Referer': 'https://stats.nba.com/',
    'Accept-Encoding': 'gzip, deflate, br',
    'Accept-Language': 'en-US,en;q=0.9',
}

parameters = {
            'Counter': 1000,
            'DateFrom': '',
            'DateTo': '',
            'Direction': "DESC",
            'LeagueID': "00",
            'PlayerOrTeam': "T",
            'Season': "2022-23",
            'SeasonType': "Regular Season",
            'Sorter': "DATE",
            }

columns_list = {
                0:"TEAM_ID", 
                1:"TEAM_NAME",
                2:"GP",
                3:"W",
                4:"L",
                5:"W_PCT",
                6:"MIN",
                7:"FGM",
                8:"FGA",
                9:"FG_PCT",
                10:"FG3M",
                11:"FG3A",
                12:"FG3_PCT",
                13:"FTM",
                14:"FTA",
                15:"FT_PCT",
                16:"OREB",
                17:"DREB",
                18:"REB",
                19:"AST",
                20:"TOV",
                21:"STL",
                22:"BLK",
                23:"BLKA",
                24:"PF",
                25:"PFD",
                26:"PTS",
                27:"PLUS_MINUS",
                28:"GP_RANK",
                29:"W_RANK",
                30:"L_RANK",
                31:"W_PCT_RANK",
                32:"MIN_RANK",
                33:"FGM_RANK",
                34:"FGA_RANK",
                35:"FG_PCT_RANK",
                36:"FG3M_RANK",
                37:"FG3A_RANK",
                38:"FG3_PCT_RANK",
                39:"FTM_RANK",
                40:"FTA_RANK",
                41:"FT_PCT_RANK",
                42:"OREB_RANK",
                43:"DREB_RANK",
                44:"REB_RANK",
                45:"AST_RANK",
                46:"TOV_RANK",
                47:"STL_RANK",
                48:"BLK_RANK",
                49:"BLKA_RANK",
                50:"PF_RANK",
                51:"PFD_RANK",
                52:"PTS_RANK",
                53:"PLUS_MINUS_RANK"
                }

game_dates = pd.read_excel('box_scores_Regular+Season.xlsx')
game_dates = game_dates['GAME_DATE'] + "-" + game_dates['season_id']
game_dates.drop_duplicates(inplace=True)
game_dates = game_dates.to_list()

dfs=[]
for game_date in tqdm.tqdm(game_dates):
    gm_dt = game_date
    game_date = game_date.split('-')
    season = game_date[3]
    season_s = season.split('_')
#for season_id in season_list:
    games_info_url = f'https://stats.nba.com/stats/leaguedashteamstats?Conference=&DateFrom=&DateTo={game_date[1]}%2F{game_date[2]}%2F{game_date[0]}&Division=&GameScope=&GameSegment=&Height=&LastNGames=0&LeagueID=00&Location=&MeasureType=Base&Month=0&OpponentTeamID=0&Outcome=&PORound=0&PaceAdjust=N&PerMode=PerGame&Period=0&PlayerExperience=&PlayerPosition=&PlusMinus=N&Rank=N&Season={season_s[0]}-{season_s[1]}&SeasonSegment=&SeasonType=Regular%20Season&ShotClockRange=&StarterBench=&TeamID=0&TwoWay=0&VsConference=&VsDivision='
    #json response
    response = requests.get(url=games_info_url, headers=headers).json()
    #pulling just desired data
    games_info = response['resultSets'][0]['rowSet']
    df = pd.DataFrame(games_info)
    df['GAME_DATE'] = gm_dt
    df['SEASON'] = season
    #print(gm_dt)
    #print(f'{game_date[1]}%2F{game_date[2]}%2F{game_date[0]}')
    dfs.append(df) 

final_df = pd.concat(dfs)

final_df = final_df.rename(columns=columns_list)

final_df.to_excel('test_v2.xlsx')
# Out:
#  11%|█         | 104/955 [00:12<01:44,  8.13it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 102
#     100 games_info_url = f'https://stats.nba.com/stats/leaguedashteamstats?Conference=&DateFrom=&DateTo={game_date[1]}%2F{game_date[2]}%2F{game_date[0]}&Division=&GameScope=&GameSegment=&Height=&LastNGames=0&LeagueID=00&Location=&MeasureType=Base&Month=0&OpponentTeamID=0&Outcome=&PORound=0&PaceAdjust=N&PerMode=PerGame&Period=0&PlayerExperience=&PlayerPosition=&PlusMinus=N&Rank=N&Season={season_s[0]}-{season_s[1]}&SeasonSegment=&SeasonType=Regular%20Season&ShotClockRange=&StarterBench=&TeamID=0&TwoWay=0&VsConference=&VsDivision='
#     101 #json response
# --> 102 response = requests.get(url=games_info_url, headers=headers).json()
#     103 #pulling just desired data
#     104 games_info = response['resultSets'][0]['rowSet']
#
# ...

# %%
import pandas as pd
import requests
import json

game_dates = pd.read_excel('box_scores_Regular+Season.xlsx')
game_dates = game_dates['GAME_DATE'] + "-" + game_dates['season_id']
game_dates.drop_duplicates(inplace=True)
game_dates = game_dates.to_list()

dfs=[]
for game_date in game_dates:
    gm_dt = game_date
    game_date = game_date.split('-')
    season = game_date[3]
    season = season.split('_')
    print(season)
# Out:
# ['2022', '23']
# ['2022', '23']
# ['2022', '23']
# ['2022', '23']
# ['2022', '23']
# ['2022', '23']
# ['2022', '23']
# ['2022', '23']
# ['2022', '23']
# ['2022', '23']
# ['2022', '23']
# ['2022', '23']
# ['2022', '23']
# ['2022', '23']
# ['2022', '23']
# ['2022', '23']
# ['2022', '23']
# ['2022', '23']
# ['2022', '23']
# ['2022', '23']
# ['2022', '23']
# ['2022', '23']
# ['2022', '23']
# ['2022', '23']
# ['2022', '23']
# ['2022', '23']
# ['2022', '23']
# ['2022', '23']
# ['2022', '23']
# ['2022', '23']
# ['2022', '23']
# ['2022', '23']
# ['2022', '23']
# ['2022', '23']
# ['2022', '23']
# ['2022', '23']
# ['2022', '23']
# ['2022', '23']
# ['2022', '23']
# ['2022', '23']
# ['2022', '23']
# ['2022', '23']
# ['2022', '23']
# ['2022', '23']
# ['2022', '23']
# ['2022', '23']
# ['2022', '23']
# ['2022', '23']
# ['2022', '23']
# ['2022', '23']
# ['2022', '23']
# ['2022', '23']
# ['2022', '23']
# ['2022', '23']
# ['2022', '23']
# ['2022', '23']
# ['2022', '23']
# ['2022', '23']
# ...

# %%
# Write file to xlsx
final_dfs = pd.concat(dfs, sort=False)
final_dfs.head()
final_dfs.to_excel("nba_game_stats_2022-23.xlsx")

# %%
import pandas as pd
import requests
import json

df = pd.read_excel('games.xlsx')

# %%
team_id = 1610612738
season = '2017-18'
df[(df['season_id'] == season) & (df['TEAM_ID'] == team_id)].head(4)
# Out:
#      Unnamed: 0  SEASON_ID     TEAM_ID TEAM_ABBREVIATION       TEAM_NAME  \
# 0          2456      22017  1610612738               BOS  Boston Celtics
# 16         2446      22017  1610612738               BOS  Boston Celtics
# 34         2410      22017  1610612738               BOS  Boston Celtics
# 103        2359      22017  1610612738               BOS  Boston Celtics
#
#       GAME_ID   GAME_DATE      MATCHUP WL  MIN  ...  REB  AST  STL  BLK  TOV  \
# 0    21700001  2017-10-17    BOS @ CLE  L  240  ...   46   24   11    4   12
# 16   21700007  2017-10-18  BOS vs. MIL  L  240  ...   43   23   12    2   15
# 34   21700019  2017-10-20    BOS @ PHI  W  240  ...   55   16    4    5   19
# 103  21700051  2017-10-24  BOS vs. NYK  W  240  ...   41   26   11    7   14
#
#      PF  PTS  PLUS_MINUS  VIDEO_AVAILABLE  season_id
# 0    24   99          -3                1    2017-18
# 16   27  100          -8                1    2017-18
# 34   24  102          10                1    2017-18
# ...

# %%
df.loc[(df['season_id'] == season) & (df['TEAM_ID'] == team_id), 'GAME_N'] = range(1,83)

# %%
df[(df['season_id'] == season) & (df['TEAM_ID'] == team_id)]
# Out:
#       Unnamed: 0  SEASON_ID     TEAM_ID TEAM_ABBREVIATION       TEAM_NAME  \
# 0           2456      22017  1610612738               BOS  Boston Celtics
# 16          2446      22017  1610612738               BOS  Boston Celtics
# 34          2410      22017  1610612738               BOS  Boston Celtics
# 103         2359      22017  1610612738               BOS  Boston Celtics
# 133         2327      22017  1610612738               BOS  Boston Celtics
# ...          ...        ...         ...               ...             ...
# 2337         113      22017  1610612738               BOS  Boston Celtics
# 2372          92      22017  1610612738               BOS  Boston Celtics
# 2397          59      22017  1610612738               BOS  Boston Celtics
# 2431          31      22017  1610612738               BOS  Boston Celtics
# 2454          18      22017  1610612738               BOS  Boston Celtics
#
#        GAME_ID   GAME_DATE      MATCHUP WL  MIN  ...  AST  STL  BLK  TOV  PF  \
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'SEASON_ID', 'TEAM_ID', 'TEAM_ABBREVIATION', 'TEAM_NAME',
#        'GAME_ID', 'GAME_DATE', 'MATCHUP', 'WL', 'MIN', 'FGM', 'FGA', 'FG_PCT',
#        'FG3M', 'FG3A', 'FG3_PCT', 'FTM', 'FTA', 'FT_PCT', 'OREB', 'DREB',
#        'REB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'PLUS_MINUS',
#        'VIDEO_AVAILABLE', 'season_id', 'GAME_N'],
#       dtype='object')

# %%
import pandas as pd

games = pd.read_excel('games_list_Regular+Season.xlsx')

# %%
game = 22200732
df_home = games.loc[games['GAME_ID'] == game]
df_home = df_home[df_home['MATCHUP'].str.contains('vs.')]
df_home
# Out:
#       Unnamed: 0  SEASON_ID     TEAM_ID TEAM_ABBREVIATION          TEAM_NAME  \
# 6165        6165      22022  1610612766               CHA  Charlotte Hornets
#
#        GAME_ID   GAME_DATE      MATCHUP WL  MIN  ...  AST  STL  BLK  TOV  PF  \
# 6165  22200732  2023-01-26  CHA vs. CHI  W  240  ...   24    8    5   16  19
#
#       PTS  PLUS_MINUS  VIDEO_AVAILABLE  season_id  GAME_N
# 6165  111          15                1    2022-23      50
#
# [1 rows x 32 columns]

# %%
games.loc[games['TEAM_ID'] == 1610612764]
# Out:
#      Unnamed: 0  SEASON_ID     TEAM_ID TEAM_ABBREVIATION           TEAM_NAME  \
# 0             0      22022  1610612764               WAS  Washington Wizards
# 1             1      22022  1610612764               WAS  Washington Wizards
# 2             2      22022  1610612764               WAS  Washington Wizards
# 3             3      22022  1610612764               WAS  Washington Wizards
# 4             4      22022  1610612764               WAS  Washington Wizards
# ..          ...        ...         ...               ...                 ...
# 467         467      22017  1610612764               WAS  Washington Wizards
# 468         468      22017  1610612764               WAS  Washington Wizards
# 469         469      22017  1610612764               WAS  Washington Wizards
# 470         470      22017  1610612764               WAS  Washington Wizards
# 471         471      22017  1610612764               WAS  Washington Wizards
#
# ...

# %%
import pandas as pd
import tqdm

teams_stats = pd.read_excel('team_stats.xlsx')
games = pd.read_excel('games_list_Regular+Season.xlsx')

games_ids = games['GAME_ID']
games_ids.drop_duplicates(inplace=True)

df_h = []
df_a = []

for game in tqdm.tqdm(games_ids):
    df = games.loc[games['GAME_ID'] == game]
    df_home = df[df['MATCHUP'].str.contains('vs.')]
    df_home = df_home.iloc[0]
    df_away = df[df['MATCHUP'].str.contains('@')]
    df_away = df_away.iloc[0]
    df_h.append(df_home)
    df_a.append(df_away)

df_h = pd.DataFrame(df_h)
df_a = pd.DataFrame(df_a)
# Out:
# 100%|██████████| 7059/7059 [00:09<00:00, 766.84it/s]

# %%
import pandas as pd

df = pd.read_excel('team_stats_Regular+Season.xlsx')

df['SEASON'].replace('_', '-', inplace=True, regex=True)

# %%
import pandas as pd 
teams_stats = pd.read_excel('team_stats_Regular+Season.xlsx')

# %%
for gp in teams_stats['GP']:
    teams_stats['GAME_N'] = teams_stats['GP'] + 1
teams_stats
# Out:
#        Unnamed: 0     TEAM_ID              TEAM_NAME  GP   W   L  W_PCT   MIN  \
# 0               0  1610612738         Boston Celtics   1   0   1  0.000  48.0
# 1               1  1610612739    Cleveland Cavaliers   1   1   0  1.000  48.0
# 2               2  1610612744  Golden State Warriors   1   0   1  0.000  48.0
# 3               3  1610612745        Houston Rockets   1   1   0  1.000  48.0
# 4               0  1610612737          Atlanta Hawks   1   1   0  1.000  48.0
# ...           ...         ...                    ...  ..  ..  ..    ...   ...
# 14113          25  1610612758       Sacramento Kings  82  48  34  0.585  48.4
# 14114          26  1610612759      San Antonio Spurs  82  22  60  0.268  48.4
# 14115          27  1610612761        Toronto Raptors  82  41  41  0.500  48.3
# 14116          28  1610612762              Utah Jazz  82  37  45  0.451  48.3
# 14117          29  1610612764     Washington Wizards  82  35  47  0.427  48.2
#
# ...

# %%
for gp in teams_stats['GP']:
    teams_stats['COMPARE'] = teams_stats['GAME_N'].astype(str) + '-' + teams_stats['TEAM_ID'].astype(str) + '-' + teams_stats['SEASON']
teams_stats
# Out:
#        Unnamed: 0     TEAM_ID              TEAM_NAME  GP   W   L  W_PCT   MIN  \
# 0               0  1610612738         Boston Celtics   1   0   1  0.000  48.0
# 1               1  1610612739    Cleveland Cavaliers   1   1   0  1.000  48.0
# 2               2  1610612744  Golden State Warriors   1   0   1  0.000  48.0
# 3               3  1610612745        Houston Rockets   1   1   0  1.000  48.0
# 4               0  1610612737          Atlanta Hawks   1   1   0  1.000  48.0
# ...           ...         ...                    ...  ..  ..  ..    ...   ...
# 14113          25  1610612758       Sacramento Kings  82  48  34  0.585  48.4
# 14114          26  1610612759      San Antonio Spurs  82  22  60  0.268  48.4
# 14115          27  1610612761        Toronto Raptors  82  41  41  0.500  48.3
# 14116          28  1610612762              Utah Jazz  82  37  45  0.451  48.3
# 14117          29  1610612764     Washington Wizards  82  35  47  0.427  48.2
#
# ...

# %%
teams_stats['GAME_N']
# Out:
# '0         2\n1         2\n2         2\n3         2\n4         2\n         ..\n14113    83\n14114    83\n14115    83\n14116    83\n14117    83\nName: GAME_N, Length: 14118, dtype: int64'

# %%
teams_stats['COMPARE']
# Out:
# 0        0         2\n1         2\n2         2\n3      ...
# 1        0         2\n1         2\n2         2\n3      ...
# 2        0         2\n1         2\n2         2\n3      ...
# 3        0         2\n1         2\n2         2\n3      ...
# 4        0         2\n1         2\n2         2\n3      ...
#                                ...
# 14113    0         2\n1         2\n2         2\n3      ...
# 14114    0         2\n1         2\n2         2\n3      ...
# 14115    0         2\n1         2\n2         2\n3      ...
# 14116    0         2\n1         2\n2         2\n3      ...
# 14117    0         2\n1         2\n2         2\n3      ...
# Name: COMPARE, Length: 14118, dtype: object

# %%
import pandas as pd

df = pd.DataFrame({'col1': [1, 2, 3], 'col2': [4, 5, 6], 'col3': [0, 0, 0]})

df.loc[(df['col1'] == 2) & (df['col2'] == 5), 'col3'] = 100

print(df)
# Out:
#    col1  col2  col3
# 0     1     4     0
# 1     2     5   100
# 2     3     6     0

# %%
# Import Libs

from tkinter import *

root = Tk()
root.title("Select NBA Season(s)")
root.geometry("670x320")

my_entries = []

def command_select_seasons():

    entry_list = ''

    for entries in my_entries:
        entry_list = entry_list + str(entries.get()) + '\n'
        my_label.config(text=entry_list)

for x in range(5):
    my_entry = Entry(root)
    my_entry.grid(row=0, column=x, pady=20, padx=5)
    my_entries.append(my_entry)

my_button = Button(root, text="Select", command=command_select_seasons)
my_button.grid(row=2, column=2, pady=20)

my_label = Label(root, text='')
my_label.grid(row=2, column=3, pady=20)

root.mainloop()
